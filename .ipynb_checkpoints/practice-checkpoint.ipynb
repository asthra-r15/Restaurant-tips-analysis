# %%
import pandas as pd
df=pd.read_csv("tips.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df=pd.read_csv("tips.csv")
#       3 df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 195.0 kB/s eta 0:00:48
#    -- ------------------------------------- 0.5/9.7 MB 195.0 kB/s eta 0:00:48
# ...

# %%
import pandas as pd
df=pd.read_csv("tips.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    str
#  3   smoker      244 non-null    str
#  4   day         244 non-null    str
#  5   time        244 non-null    str
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 13.5 KB

# %% [raw]
# print(df.duplicated())

# %%
print("average:",df["tip"].mean())
# Out:
# average: 2.99827868852459

# %%
print("max bil:",df["tip"].max())
# Out:
# max bil: 10.0

# %%
print("min bil:",df["total_bill"].min())
# Out:
# min bil: 3.07

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.groupby("day")["tip"].max().idxmax()
# Out:
# 'Sat'

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby("sex")["tip"].mean()
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
df.groupby("day")["tip"].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
df.groupby("time")["total_bill"].mean().idxmax()
# Out:
# 'Dinner'

# %%
import pandas as pd
df=pd.read_csv("tips.csv")
x=0
for i in df["tip"]:
    if i > 5.00:
        x+=1
print(x)
# Out:
# 18

# %%
df.groupby("time")["total_bill"].mean().idxmax()
# Out:
# 'Dinner'

# %%
df[df["tip"]>5]
df.groupby("day").size()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# dtype: int64

# %%
df[df["tip"]>5]
df.groupby("day").size().idxmax()
# Out:
# 'Sat'

# %%
df.groupby("time")["tip"].mean().idxmax()
# Out:
# 'Dinner'

# %%
import matplotlib.pyplot as plt
df["tip"].hist()
plt.show()

# %%
df.groupby("day")["total_bill"].sum()
# Out:
# day
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33
# Name: total_bill, dtype: float64

# %%
df.groupby("day")["tip"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='day'>

# %%
df.groupby("day")["tip"].mean().plot(kind="pie")
# Out:
# <Axes: >

# %%
df.groupby("day")["total_bill"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='day'>

# %%
df.groupby("day")["tip"].mean().hist()
# Out:
# <Axes: >
